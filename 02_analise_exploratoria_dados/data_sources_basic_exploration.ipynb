# %% [markdown]
# # Exploração Básica das Fontes de Dados

# %% [markdown]
# ## Configuração do Ambiente

# %%
from pyspark.sql import functions as F

catalog = "dados_gov"
schema = "imposto_de_renda_data_sources"

# %% [markdown]
# ## Ingestão de Tabelas e Análise Básica de Dados

# %% [markdown]
# ### Tabela de Ativos e Direitos

# %%
df_assets_and_rights = spark.table(f"{catalog}.{schema}.bens_e_direitos")

display(df_assets_and_rights)

# %%
df_colunm_qtt = spark.createDataFrame([(len(df_assets_and_rights.columns),)], ["num_columns"])
display(df_colunm_qtt)

# %% [markdown]
# ### Estado de Residência Capital do Declarante Tabela

# %%
df_state_of_residence_capital_of_the_declarant = spark.table(
    f"{catalog}.{schema}.capital_de_estado_de_residencia_do_declarante"
)

display(df_state_of_residence_capital_of_the_declarant)

# %%
display(df_state_of_residence_capital_of_the_declarant.groupBy("capital_estado").agg(F.count("*")).alias("count"))

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.num_columns + len(df_state_of_residence_capital_of_the_declarant.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_state_of_residence_capital_of_the_declarant.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de Dívidas e Passivos

# %%
df_debts_and_liabilities = spark.table(
    f"{catalog}.{schema}.dividas_e_onus"
)

display(df_debts_and_liabilities)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_debts_and_liabilities.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_debts_and_liabilities.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Estado de Residência do Declarante (Tabela)

# %%
df_state_of_residence_capital_of_the_declarant = spark.table(
    f"{catalog}.{schema}.capital_de_estado_de_residencia_do_declarante"
)

display(df_state_of_residence_capital_of_the_declarant)

# %%
display(df_state_of_residence_capital_of_the_declarant.groupBy("capital_estado").agg(F.count("*")).alias("count"))

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_state_of_residence_capital_of_the_declarant.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_state_of_residence_capital_of_the_declarant.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de Faixa Etária e Sexo do Declarante

# %%
df_declarant_age_range_and_gender = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/faixa-etaria-do-declarante-e-genero.csv")

display(df_declarant_age_range_and_gender)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_declarant_age_range_and_gender.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_declarant_age_range_and_gender.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de intervalo base de cálculo anual

# %%
df_annual_calculation_base_range = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/faixa-de-base-de-calculo-anual.csv")

display(df_annual_calculation_base_range)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_annual_calculation_base_range.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_annual_calculation_base_range.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Faixa base para cálculo do salário mínimo e gênero

# %%
df_base_range_for_calculation_in_minimum_wages_and_gender = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/faixa-de-base-de-calculo-em-salarios-minimos-e-genero.csv")

display(df_base_range_for_calculation_in_minimum_wages_and_gender)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_base_range_for_calculation_in_minimum_wages_and_gender.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_base_range_for_calculation_in_minimum_wages_and_gender.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de Intervalos de Doações e Heranças

# %%
df_donation_and_inheritance_range = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/faixa-de-doacoes-e-herancas.csv")

display(df_donation_and_inheritance_range)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_donation_and_inheritance_range.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_donation_and_inheritance_range.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Faixa de rendimento bruto tributável na tabela de salários mínimos

# %%
df_range_of_gross_taxable_income_in_minimum_wages = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/faixa-de-rendimento-tributavel-bruto-em-salarios-minimos.csv")

display(df_range_of_gross_taxable_income_in_minimum_wages)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_range_of_gross_taxable_income_in_minimum_wages.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_range_of_gross_taxable_income_in_minimum_wages.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de Faixa de Renda Tributável Excluindo a Tributação sobre o Salário Mínimo

# %%
df_taxable_income_range_exclusive_taxation_on_minimum_wages = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/faixa-de-rendimentos-tributaveis-tributacao-exclusiva-em-salarios-minimos.csv")

display(df_taxable_income_range_exclusive_taxation_on_minimum_wages)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_taxable_income_range_exclusive_taxation_on_minimum_wages.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_taxable_income_range_exclusive_taxation_on_minimum_wages.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Faixa de Renda Total na Tabela de Salários Mínimos

# %%
df_range_of_total_income_in_minimum_wages = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/faixa-de-rendimentos-totais-em-salarios-minimos.csv")

display(df_range_of_total_income_in_minimum_wages)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_range_of_total_income_in_minimum_wages.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_range_of_total_income_in_minimum_wages.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de Gênero e Tipo de Declaração

# %%
df_gender_and_declaration_type = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/genero-e-tipo-de-declaracao.csv")

display(df_gender_and_declaration_type)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_gender_and_declaration_type.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_gender_and_declaration_type.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Município de Residência do Declarante Tabela

# %%
df_municipality_of_residence = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/municipio-de-residencia-do-declarante-e-tipo-de-formulario.csv")

display(df_municipality_of_residence)

# %%
df_municipality_of_residence.count()

# %%
display(df_municipality_of_residence.groupBy("Ano-Calendário").agg(F.count("*").alias("qtd")))

# %%
display(df_municipality_of_residence.groupBy("Município").agg(F.count("*").alias("qtd")))

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_municipality_of_residence.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_municipality_of_residence.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de Natureza da Ocupação

# %%
df_nature_of_occupation = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/natureza-de-ocupacao.csv")

display(df_nature_of_occupation)

# %%
display(df_nature_of_occupation.groupBy("Ano-Calendário").agg(F.count("*").alias("qtd")))

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_nature_of_occupation.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_nature_of_occupation.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Principal ocupação da mesa do declarante

# %%
df_main_occupation = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/ocupacao-principal-do-declarante.csv")

display(df_main_occupation)

# %%
display(df_main_occupation.groupBy("Ano-Calendário").agg(F.count("*").alias("qtd")))

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_main_occupation.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_main_occupation.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de Pagamentos e Doações

# %%
df_payments_and_donations = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/pagamentos-e-doacoes.csv")

display(df_payments_and_donations)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_payments_and_donations.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_payments_and_donations.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela com os beneficiários de lucros e dividendos, além da renda do sócio e do proprietário da microempresa, por faixa de renda total (em salários mínimos).

# %%
df_profit_dividend_recipients_and_partner_owner_income_by_total_income_range_in_minimum_wages = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/recebedores-de-lucros-e-dividendos-rend-socio-e-titular-microempresa-por-faixa-de-rendimento-total-em-salarios-minimos.csv")

display(df_profit_dividend_recipients_and_partner_owner_income_by_total_income_range_in_minimum_wages)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_profit_dividend_recipients_and_partner_owner_income_by_total_income_range_in_minimum_wages.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_profit_dividend_recipients_and_partner_owner_income_by_total_income_range_in_minimum_wages.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de beneficiários de lucros e dividendos + rendimentos de sócios e proprietários de microempresas por ocupação principal

# %%
df_profit_dividend_recipients_and_partner_owner_income_by_main_occupation = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/recebedores-de-lucros-e-dividendos-rend-socio-e-titular-microempresa-por-ocupacao-principal.csv")

display(df_profit_dividend_recipients_and_partner_owner_income_by_main_occupation)

# %%
display(df_profit_dividend_recipients_and_partner_owner_income_by_main_occupation.groupBy("Ocupação Principal do Declarante").agg(F.count("*").alias("qtd")))

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_profit_dividend_recipients_and_partner_owner_income_by_main_occupation.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_profit_dividend_recipients_and_partner_owner_income_by_main_occupation.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Rendimentos sujeitos à tabela de tributação exclusiva/definitiva

# %%
df_income_subject_to_exclusive_definitive_taxation = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/rendimentos-sujeitos-a-tributacao-exclusiva-definitiva.csv")

display(df_income_subject_to_exclusive_definitive_taxation)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_income_subject_to_exclusive_definitive_taxation.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_income_subject_to_exclusive_definitive_taxation.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de rendimentos tributáveis ​​por faixa salarial mínima

# %%
df_taxable_income_by_minimum_wage_range = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/rendimentos-tributaveis-por-faixa-de-salarios-minimos.csv")

display(df_taxable_income_by_minimum_wage_range)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_taxable_income_by_minimum_wage_range.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_taxable_income_by_minimum_wage_range.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de rendimentos isentos e não tributáveis

# %%
df_tax_exempt_and_non_taxable_income = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/rendimentos-isentos-e-nao-tributaveis.csv")

display(df_tax_exempt_and_non_taxable_income)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_tax_exempt_and_non_taxable_income.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_tax_exempt_and_non_taxable_income.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tabela de Situação Fiscal

# %%
df_tax_status = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/situacao-fiscal.csv")

display(df_tax_status)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_tax_status.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_tax_status.columns)))
display(df_colunm_qtt)

# %% [markdown]
# ### Tipo de tabela de formulário

# %%
df_form_type = spark.read.format("csv").option("header", "true").option("delimiter", ";").load("/Volumes/fiap_1ctor/data_sources/data_sources/tipo-de-formulario.csv")

display(df_form_type)

# %%
df_colunm_qtt = df_colunm_qtt.withColumn("total_columns", df_colunm_qtt.total_columns + len(df_form_type.columns))
df_colunm_qtt = df_colunm_qtt.withColumn("num_columns", F.lit(len(df_form_type.columns)))
display(df_colunm_qtt)
